# %%
from keras import layers
from keras import models

model = models.Sequential()
# CNN
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1))) # 26X26
model.add(layers.MaxPooling2D((2, 2))) # 13 X 13
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# CNN end -> features map

model.add(layers.Flatten()) # convert into in 1d

# classifer
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax')) # last layer 10 distributions
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 3, 3, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 576)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 93,322 (364.54 KB)
#  Trainable params: 93,322 (364.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.datasets import mnist
from keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255 # training data normalization

test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255 # testing data normalization

train_labels = to_categorical(train_labels) # one-hot-encoding
test_labels = to_categorical(test_labels) # one-hot-encoding


model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8688 - loss: 0.4076
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9835 - loss: 0.0511
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9892 - loss: 0.0332
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9921 - loss: 0.0239
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9939 - loss: 0.0212

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(test_loss, test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9887 - loss: 0.0330
# 0.024517543613910675 0.9919000267982483

# %%
# Incorrect: Missing closing quote
# !wget -O dogs-vs-cats.zip "https://example.com/path/to/dogs-vs-cats.zip"
# Out:
# --2024-11-23 12:17:13--  https://example.com/path/to/dogs-vs-cats.zip
# Resolving example.com (example.com)... 93.184.215.14, 2606:2800:21f:cb07:6820:80da:af6b:8b2c
# Connecting to example.com (example.com)|93.184.215.14|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-11-23 12:17:13 ERROR 404: Not Found.

# %%
# prompt: i have "/content/kaggle.json" now i have to download data dogs-vs-cats from kaggle

import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content"

# !kaggle datasets download -d biaiscience/dogs-vs-cats

# !unzip dogs-vs-cats.zip -d /content/dogs-vs-cats
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dogs-vs-cats/train/train/dog.5499.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.55.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.550.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5500.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5501.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5502.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5503.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5504.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5505.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5506.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5507.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5508.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5509.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.551.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5510.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5511.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5512.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5513.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5514.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5515.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5516.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5517.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5518.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5519.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.552.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5520.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5521.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5522.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5523.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5524.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5525.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5526.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5527.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5528.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5529.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.553.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5530.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5531.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5532.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5533.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5534.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5535.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5536.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5537.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5538.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5539.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.554.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5540.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5541.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5542.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5543.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5544.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5545.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5546.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5547.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5548.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5549.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.555.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5550.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5551.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5552.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5553.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5554.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5555.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5556.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5557.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5558.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5559.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.556.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5560.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5561.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5562.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5563.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5564.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5565.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5566.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5567.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5568.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5569.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.557.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5570.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5571.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5572.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5573.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5574.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5575.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5576.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5577.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5578.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5579.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.558.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5580.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5581.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5582.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5583.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5584.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5585.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5586.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5587.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5588.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5589.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.559.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5590.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5591.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5592.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5593.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5594.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5595.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5596.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5597.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5598.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5599.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.56.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.560.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5600.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5601.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5602.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5603.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5604.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5605.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5606.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5607.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5608.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5609.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.561.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5610.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5611.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5612.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5613.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5614.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5615.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5616.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5617.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5618.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5619.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.562.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5620.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5621.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5622.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5623.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5624.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5625.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5626.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5627.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5628.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5629.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.563.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5630.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5631.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5632.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5633.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5634.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5635.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.5636.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.
jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9854.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9855.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9856.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9857.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9858.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9859.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.986.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9860.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9861.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9862.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9863.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9864.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9865.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9866.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9867.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9868.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9869.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.987.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9870.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9871.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9872.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9873.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9874.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9875.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9876.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9877.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9878.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9879.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.988.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9880.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9881.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9882.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9883.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9884.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9885.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9886.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9887.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9888.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9889.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.989.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9890.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9891.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9892.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9893.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9894.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9895.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9896.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9897.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9898.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9899.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.99.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.990.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9900.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9901.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9902.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9903.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9904.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9905.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9906.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9907.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9908.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9909.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.991.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9910.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9911.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9912.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9913.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9914.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9915.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9916.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9917.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9918.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9919.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.992.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9920.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9921.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9922.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9923.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9924.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9925.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9926.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9927.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9928.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9929.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.993.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9930.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9931.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9932.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9933.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9934.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9935.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9936.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9937.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9938.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9939.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.994.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9940.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9941.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9942.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9943.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9944.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9945.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9946.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9947.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9948.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9949.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.995.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9950.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9951.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9952.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9953.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9954.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9955.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9956.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9957.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9958.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9959.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.996.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9960.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9961.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9962.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9963.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9964.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9965.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9966.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9967.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9968.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9969.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.997.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9970.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9971.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9972.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9973.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9974.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9975.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9976.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9977.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9978.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9979.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.998.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9980.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9981.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9982.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9983.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9984.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9985.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9986.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9987.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9988.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9989.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.999.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9990.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9991.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9992.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9993.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9994.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9995.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9996.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9997.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9998.jpg
#   inflating: /content/dogs-vs-cats/train/train/dog.9999.jpg

# %%
# !nvidia-smi
# Out:
# Sat Nov 23 12:35:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os, shutil
original_dataset_dir = '/content/dogs-vs-cats/train/train'
base_dir = '/content/dog_cat1/'

os.mkdir(base_dir)

train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)
train_cats_dir = os.path.join(train_dir, 'cats')
os.mkdir(train_cats_dir)
train_dogs_dir = os.path.join(train_dir, 'dogs')
os.mkdir(train_dogs_dir)
validation_cats_dir = os.path.join(validation_dir, 'cats')
os.mkdir(validation_cats_dir)
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
os.mkdir(validation_dogs_dir)
test_cats_dir = os.path.join(test_dir, 'cats')
os.mkdir(test_cats_dir)
test_dogs_dir = os.path.join(test_dir, 'dogs')
os.mkdir(test_dogs_dir)
fnames = ['cat.{}.jpg'.format(i) for i in range(1000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_cats_dir, fname)
    shutil.copyfile(src, dst)
fnames = ['cat.{}.jpg'.format(i) for i in range(1000, 1500)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_cats_dir, fname)
    shutil.copyfile(src, dst)
fnames = ['cat.{}.jpg'.format(i) for i in range(1500, 2000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_cats_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['dog.{}.jpg'.format(i) for i in range(1000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_dogs_dir, fname)
    shutil.copyfile(src, dst)
fnames = ['dog.{}.jpg'.format(i) for i in range(1000, 1500)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_dogs_dir, fname)
    shutil.copyfile(src, dst)
    fnames = ['dog.{}.jpg'.format(i) for i in range(1500, 2000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_dogs_dir, fname)
    shutil.copyfile(src, dst)

# %%
print('total training cat images:', len(os.listdir(train_cats_dir)))

print('total training dog images:', len(os.listdir(train_dogs_dir)))

print('total validation cat images:', len(os.listdir(validation_cats_dir)))

print('total validation dog images:', len(os.listdir(validation_dogs_dir)))

print('total test cat images:', len(os.listdir(test_cats_dir)))

print('total test dog images:', len(os.listdir(test_dogs_dir)))
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# total test cat images: 500
# total test dog images: 500

# %%
from tensorflow.keras import layers
from tensorflow.keras import models
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 34, 34, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 17, 17, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 15, 15, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       3,211,776 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,453,121 (13.17 MB)
#  Trainable params: 3,453,121 (13.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import optimizers
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(),
              metrics=['acc'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        target_size=(150, 150),
                                                        batch_size=20,
                                                        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=100,
    epochs=30,
    validation_data=validation_generator,
    validation_steps=50)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - acc: 0.5210 - loss: 0.7104 - val_acc: 0.5010 - val_loss: 0.6951
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 195us/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/30
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - acc: 0.5052 - loss: 0.6954 - val_acc: 0.5750 - val_loss: 0.6834
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - acc: 0.5706 - loss: 0.6848 - val_acc: 0.5570 - val_loss: 0.6709
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - acc: 0.6496 - loss: 0.6440 - val_acc: 0.5410 - val_loss: 0.6874
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 129us/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - acc: 0.6678 - loss: 0.5919 - val_acc: 0.6560 - val_loss: 0.6110
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 132us/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - acc: 0.6867 - loss: 0.5798 - val_acc: 0.6910 - val_loss: 0.5693
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 138us/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - acc: 0.7079 - loss: 0.5491 - val_acc: 0.6830 - val_loss: 0.5992
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - acc: 0.7496 - loss: 0.5030 - val_acc: 0.7080 - val_loss: 0.5896
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126us/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - acc: 0.7970 - loss: 0.4287 - val_acc: 0.6850 - val_loss: 0.6494
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - acc: 0.8183 - loss: 0.4098 - val_acc: 0.6960 - val_loss: 0.6105
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - acc: 0.8544 - loss: 0.3264 - val_acc: 0.6810 - val_loss: 0.8577
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 161us/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - acc: 0.8693 - loss: 0.2903 - val_acc: 0.7220 - val_loss: 0.7355
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - acc: 0.9137 - loss: 0.2059 - val_acc: 0.7260 - val_loss: 0.8368
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 140us/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - acc: 0.9410 - loss: 0.1669 - val_acc: 0.7070 - val_loss: 0.9423
# Epoch 28/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 129us/step - acc: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - acc: 0.9557 - loss: 0.1111 - val_acc: 0.7000 - val_loss: 0.8972
# Epoch 30/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 146us/step - acc: 0.0000e+00 - loss: 0.0000e+00

# %%
# model.save('cats_and_dogs_small_1.h5')
model.save('cats_and_dogs_small_1.keras')

# %%
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-2a1f94d895e5> in <cell line: 8>()
#       6 epochs = range(1, len(acc) + 1)
#       7 plt.plot(epochs, acc, 'bo', label='Training acc')
# ----> 8 plt.plot(epochs, val_acc, 'b', label='Validation acc')
#       9 plt.title('Training and validation accuracy')
#      10 plt.legend()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1719         """
#    1720         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722         for line in lines:
#    1723             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, axes, data, *args, **kwargs)
#     301                 this += args[0],
#     302                 args = args[1:]
# --> 303             yield from self._plot_args(
#     304                 axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     305
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     497
#     498         if x.shape[0] != y.shape[0]:
# --> 499             raise ValueError(f"x and y must have same first dimension, but "
#     500                              f"have shapes {x.shape} and {y.shape}")
#     501         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (30,) and (15,)
